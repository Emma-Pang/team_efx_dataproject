# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
import statsmodels.api as sm
file_to_load = "Resources/overdose-death-rates-per-population.csv"

# Read File and store into Pandas data frame
overdose_df = pd.read_csv(file_to_load,sep = ";")

overdose_df
# Out:
#            Location  Year  All Drug Overdose Death Rate (Age-Adjusted)  \
# 0          Maryland  2012                                         13.7
# 1           Arizona  2015                                         19.0
# 2           Vermont  2003                                         10.2
# 3            Kansas  2008                                          8.0
# 4             Idaho  2009                                         11.6
# ..              ...   ...                                          ...
# 862         Arizona  2000                                         10.6
# 863  North Carolina  2012                                         13.3
# 864        Nebraska  2010                                          6.7
# 865        Virginia  2006                                          8.0
# 866            Utah  2005                                         19.3
#
#     All Drug Overdose Death Rate (Age-Adjusted) (missing reason)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 862                                                NaN
# 863                                                NaN
# 864                                                NaN
# 865                                                NaN
# 866                                                NaN
#
#      Opioid Overdose Death Rate (Age-Adjusted)  \
# 0                                         10.9
# 1                                         10.2
# 2                                          7.2
# 3                                          3.5
# 4                                          4.2
# ..                                         ...
# 862                                        4.8
# 863                                        8.6
# 864                                        3.4
# 865                                        5.3
# 866                                       14.2
#
#     Opioid Overdose Death Rate (Age-Adjusted) (missing reason)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 862                                                NaN
# 863                                                NaN
# 864                                                NaN
# 865                                                NaN
# 866                                                NaN
#
#      Percent Change in All Drug Overdose Death Rate from Prior Year  \
# 0                                                 0.17
# 1                                                 0.04
# 2                                                 0.36
# 3                                                -0.20
# 4                                                 0.18
# ..                                                 ...
# 862                                               0.00
# 863                                               0.02
# 864                                               0.14
# 865                                               0.07
# 866                                               0.18
#
#     Percent Change in All Drug Overdose Death Rate from Prior Year (missing reason)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 862                                                NaN
# 863                                                NaN
# 864                                                NaN
# 865                                                NaN
# 866                                                NaN
#
#      Percent Change in Opioid Overdose Death Rate from Prior Year  \
# 0                                                 0.20
# 1                                                 0.16
# 2                                                 0.24
# 3                                                -0.20
# 4                                                -0.13
# ..                                                 ...
# 862                                               0.02
# 863                                               0.00
# 864                                              -0.08
# 865                                               0.13
# 866                                               0.20
#
#     Percent Change in Opioid Overdose Death Rate from Prior Year (missing reason)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 862                                                NaN
# 863                                                NaN
# 864                                                NaN
# 865                                                NaN
# 866                                                NaN
#
# [867 rows x 10 columns]

# %%
#group data by states
grouped_overdose_bystate = overdose_df.groupby(["Location"])
#get a serie of average opioid overdose death rate 
ave_death_rate_opioid = grouped_overdose_bystate['Opioid Overdose Death Rate (Age-Adjusted)'].mean()
#a serie of ave all drug overdose death rate 
ave_death_rate_drugs = grouped_overdose_bystate['All Drug Overdose Death Rate (Age-Adjusted)'].mean()

# %%
grouped_overdose_bystate_df = grouped_overdose_bystate.mean()
grouped_overdose_bystate_df.head()
# Out:
#             Year  All Drug Overdose Death Rate (Age-Adjusted)  \
# Location
# Alabama     2007                                     9.464706
# Alaska      2007                                    12.976471
# Arizona     2007                                    14.870588
# Arkansas    2007                                    10.000000
# California  2007                                     9.364706
#
#             Opioid Overdose Death Rate (Age-Adjusted)  \
# Location
# Alabama                                      3.000000
# Alaska                                       8.736364
# Arizona                                      7.511765
# Arkansas                                     4.841176
# California                                   4.288235
#
#             Percent Change in All Drug Overdose Death Rate from Prior Year  \
# Location
# Alabama                                              0.101875
# Alaska                                               0.076250
# Arizona                                              0.040000
# Arkansas                                             0.083750
# California                                           0.064375
#
#             Percent Change in Opioid Overdose Death Rate from Prior Year
# Location
# Alabama                                              0.164375
# Alaska                                              -0.002500
# Arizona                                              0.052500
# Arkansas                                             0.196875
# California                                           0.063125

# %%
#http://www.statsmodels.org/devel/generated/statsmodels.regression.linear_model.RegressionResults.html
#https://www.youtube.com/watch?v=g0nuuk-RGhs
y = grouped_overdose_bystate_df[['All Drug Overdose Death Rate (Age-Adjusted)']]
x = grouped_overdose_bystate_df[['Opioid Overdose Death Rate (Age-Adjusted)']]
x1 = sm.add_constant(x)
model = sm.OLS(y,x1)
fitted1 = model.fit()
fitted1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# =======================================================================================================
# Dep. Variable:     All Drug Overdose Death Rate (Age-Adjusted)   R-squared:                       0.713
# Model:                                                     OLS   Adj. R-squared:                  0.707
# Method:                                          Least Squares   F-statistic:                     121.6
# Date:                                         Mon, 09 Dec 2019   Prob (F-statistic):           7.08e-15
# Time:                                                 17:53:28   Log-Likelihood:                -105.38
# No. Observations:                                           51   AIC:                             214.8
# Df Residuals:                                               49   BIC:                             218.6
# Df Model:                                                    1
# Covariance Type:                                     nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# const                                         4.9103      0.666      7.372      0.000       3.572       6.249
# Opioid Overdose Death Rate (Age-Adjusted)     0.9755      0.088     11.028      0.000       0.798       1.153
# ==============================================================================
# Omnibus:                        2.163   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.339   Jarque-Bera (JB):                1.377
# Skew:                           0.373   Prob(JB):                        0.502
# Kurtosis:                       3.304   Cond. No.                         18.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.

# %%
fitted1.rsquared_adj
# Out:
# 0.7069426310184044
